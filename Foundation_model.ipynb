# %%
from langchain.chat_models import init_chat_model
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv # To load variables inside the .env file
from pprint import pprint # To format messy dictionary outputs to human readable output

load_dotenv()

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=0.5,
    timeout=10
)

response = model.invoke("What's the capital of the Moon?")

print(response.content)
print(response.response_metadata)
print(response.usage_metadata)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a natural celestial body, not a country or a political entity.
#
# However, if we were to imagine a "capital" in a more symbolic or historical sense, some might point to:
#
# *   **Tranquility Base:** This is where Neil Armstrong and Buzz Aldrin landed during the Apollo 11 mission in 1969. It's a hugely significant historical site for humanity's exploration of the Moon.
# *   **A hypothetical future settlement:** If humans were to establish permanent bases on the Moon, the first or most prominent one might eventually be considered a de facto capital.
#
# But officially and scientifically, there is **no capital of the Moon.**
# {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}
# {'input_tokens': 10, 'output_tokens': 163, 'total_tokens': 173, 'input_token_details': {'cache_read': 0}}

# %%
from langchain.agents import create_agent

agent=create_agent(model=model)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='7d52fb9b-de90-4c29-a145-16c4084e000e'),
#               AIMessage(content="That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body, not a country or a populated planet with governments and infrastructure.\n\nSo, the answer is: **The Moon has no capital.**", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d834b-f400-7af3-a580-539a7350d149-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 55, 'total_tokens': 65, 'input_token_details': {'cache_read': 0}})]}
# None
# None

# %%
print(response['messages'][-1].content)
# Out:
# That's a fun question! The Moon doesn't have a capital city in the way Earth does. It's a celestial body, not a country or a populated planet with governments and infrastructure.
#
# So, the answer is: **The Moon has no capital.**

# %%
# Stream that prints out output as it recieves instead of collecting fully and printing it

for token,metadata in agent.stream(
    {"messages": [HumanMessage(content="What's the fun fact abou the moon?")]},
    stream_mode='messages'
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    if token.content: # check if there's actual content
            print(token.content,end="",flush=True) # print token
# Out:
# Here's a fun fact about the Moon that often surprises people:
#
# **The Moon is slowly drifting away from Earth.**
#
# It's not a dramatic, noticeable drift, but it's happening at a rate of about **1.5 inches (3.8 centimeters) per year**.
#
# **Why is this happening?**
#
# It's due to a phenomenon called tidal acceleration. The Moon's gravity causes tides on Earth, and as Earth rotates, these tidal bulges are pulled slightly ahead of the Moon. This slight tug-of-war transfers energy from Earth's rotation to the Moon's orbit, causing the Moon to gradually move further away and Earth's rotation to slow down (though very, very gradually).
#
# **What's the implication?**
#
# *   **Future Eclipses:** In the very, very distant future (tens of millions of years from now), the Moon will appear too small in the sky to completely cover the Sun, meaning total solar eclipses as we know them won't happen anymore.
# *   **Longer Days:** Earth's days are getting longer by a tiny fraction of a second each century.
#
# It's a subtle but fascinating reminder that celestial bodies are not static!
